# %%
import requests
import json
import time

# %%
URL = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%08SSD&page=1&sort=sale/dc'

resp = requests.get(URL)
data = json.loads(resp.text)
data
# Out:
# {'QTime': 61,
#  'cateName': '',
#  'isMust': 1,
#  'prods': [{'BU': 'ec',
#    'Id': 'DRAH6C-A9008F54N',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆發揮系統極致效能\r\n◆耐用性高達200tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標)',
#    'originPrice': 2090,
#    'picB': '/items/DRAH6CA9008F54N/000001_1567649044.jpg',
#    'picS': '/items/DRAH6CA9008F54N/000002_1557821136.jpg',
#    'price': 2090,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH5E-A9007CRTN',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH5E',
#    'couponActid': [],
#    'describe': 'SanDisk 進化版 SSD Plus 240GB 2.5吋SATAIII固態硬碟\\r\\n讀530m 寫440m tlc 三年保\r\n★持續讀寫速度530mb s；440mb s\r\n★搭配sandisk頂級tlc同步顆粒\r\n★dashboard 軟體可即時監控裝置狀態及軟體更新\r\n★7mm薄型設計\r\n★三年保固\r\n★展碁國際公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SanDisk SSD Plus 240GB 2.5吋SATAIII固態硬碟(G26)',
#    'originPrice': 938,
#    'picB': '/items/DRAH5EA9007CRTN/000001_1522202196.jpg',
#    'picS': '/items/DRAH5EA9007CRTN/000002_1488791017.jpg',
#    'price': 938,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH6C-A9008F563',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 1TB 2.5吋 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆發揮系統極致效能\r\n◆持久率高達400tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 1TB 2.5吋 3D NAND固態硬碟(藍標)',
#    'originPrice': 3980,
#    'picB': '/items/DRAH6CA9008F563/000001_1567562691.jpg',
#    'picS': '/items/DRAH6CA9008F563/000002_1557820146.jpg',
#    'price': 3980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH5E-A9007CRVC',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH5E',
#    'couponActid': [],
#    'describe': 'SanDisk 進化版 SSD Plus 480GB 2.5吋SATAIII固態硬碟(G26)\\r\\n讀535m 寫450m tlc 三年保\r\n★持續讀寫速度535mb s；445mb s\r\n★搭配sandisk頂級tlc同步顆粒\r\n★dashboard 軟體可即時監控裝置狀態及軟體更新\r\n★7mm薄型設計\r\n★展碁國際公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SanDisk SSD Plus 480GB 2.5吋SATAIII固態硬碟(G26)',
#    'originPrice': 1688,
#    'picB': '/items/DRAH5EA9007CRVC/000001_1541384950.jpg',
#    'picS': '/items/DRAH5EA9007CRVC/000002_1488791045.jpg',
#    'price': 1688,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH6C-A9008F54M',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 250GB 2.5吋 3D NAND 固態硬碟\\r\\n讀550m 寫525m tlc 五年保\r\n◆連續讀取550mb s，連讀寫入525mb s \r\n◆發揮系統極致效能\r\n◆耐用性高達100tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)',
#    'originPrice': 1390,
#    'picB': '/items/DRAH6CA9008F54M/000001_1557820884.jpg',
#    'picS': '/items/DRAH6CA9008F54M/000002_1557820884.jpg',
#    'price': 1390,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7P-A9009KY3G',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH8B',
#    'couponActid': [],
#    'describe': 'SanDisk Extreme Pro 1TB M.2 NVMe 3D SSD\\r\\n★讀3 400mb 寫2 800mb 3d 五年保\r\n-連續讀取3 400mb 連續寫入2 800mb\r\n-最新ncache 3.0加速程式搭配3d nand技術\r\n-隨機讀取iops高達500 000\r\n-隨機寫入iops高達400 000\r\n-耐用性600 tbw\r\n-dashboard軟體即時監控裝置狀態及軟體更新\r\n-五年保固\r\n-展碁國際公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SanDisk Extreme Pro 1TB M.2 NVMe 3D SSD',
#    'originPrice': 5688,
#    'picB': '/items/DRAH7PA9009KY3G/000001_1542622962.jpg',
#    'picS': '/items/DRAH7PA9009KY3G/000002_1542622962.jpg',
#    'price': 5688,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7P-A9009EKFR',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH5E',
#    'couponActid': [],
#    'describe': 'SanDisk SSD Plus 1TB 2.5吋SATAIII固態硬碟(G26)\\r\\n讀535m 寫445m tlc 三年保\r\n★持續讀寫速度535mb s；445mb s\r\n★搭配sandisk頂級tlc同步顆粒\r\n★dashboard 軟體可即時監控裝置狀態及軟體更新\r\n★7mm薄型設計\r\n★展碁國際公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SanDisk SSD Plus 1TB 2.5吋SATAIII固態硬碟(G26)',
#    'originPrice': 3388,
#    'picB': '/items/DRAH7PA9009EKFR/000001_1551060528.jpg',
#    'picS': '/items/DRAH7PA9009EKFR/000002_1537158669.jpg',
#    'price': 3388,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH6C-A9008F56O',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD 藍標 BLUE 1TB M.2 2280 3D NAND SATA SSD\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆耗電量降低25%\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達400tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)',
#    'originPrice': 3980,
#    'picB': '/items/DRAH6CA9008F56O/000001_1557822086.jpg',
#    'picS': '/items/DRAH6CA9008F56O/000002_1557822086.jpg',
#    'price': 3980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7O-A9009TD47',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD 黑標 SN750 1TB NVMe PCIe SSD固態硬碟\\r\\n讀3470m 寫3000m 五年保\r\n◆連續讀取3470mb s，連讀寫入3000mb s \r\n◆發揮系統極致效能\r\n◆介面 m.2 2280*  pcie gen3 8 gb s，最多 4 個通道\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD 黑標 SN750 1TB NVMe PCIe SSD固態硬碟',
#    'originPrice': 6690,
#    'picB': '/items/DRAH7OA9009TD47/000001_1567044486.jpg',
#    'picS': '/items/DRAH7OA9009TD47/000002_1557823644.jpg',
#    'price': 6690,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH2M-A90099SG2',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH2M',
#    'couponActid': [],
#    'describe': 'Seagate Fast SSD 500GB 外接式固態硬碟\\r\\n讀540m 寫500m tlc 三年保\r\n★連續速度讀:540mb s 寫:500mb s \r\n★極至輕巧、時尚、高質感、便利好攜\r\n★提供兩個月adobe creative cloud photography計劃會員資格\r\n★附備份與資料夾鏡射軟體 輕鬆監控目標資料夾\r\n★隨附type-c轉type-a連接線\r\n★保固內可享免費資料救援一次 \r\n★三年保固\r\n\r\n【買amd x seagate 購買指定組合送好禮】\r\n|活動時間：即日起~2019 09 30止 \r\n|活動方式：單筆發票購買指定amd cpu+ seagate 任一4tb(含)以上內接硬碟或500g(含)以上固態硬碟的組合方案即可獲得xbox game pass 3個月資格 (戰爭機器5與100多款遊戲)加 seagate加碼贈送my card $150元點數 -送完為止。  \r\n|活動網址：《點我看兌換流程》\r\n※活動訊息依官網為準',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'Seagate Fast SSD 500GB 外接式固態硬碟',
#    'originPrice': 3390,
#    'picB': '/items/DRAH2MA90099SG2/000001_1545186256.jpg',
#    'picS': '/items/DRAH2MA90099SG2/000002_1533794822.jpg',
#    'price': 3390,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7A-A900959MK',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆發揮系統極致效能\r\n◆耐用性高達200tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標)',
#    'originPrice': 2190,
#    'picB': '/items/DRAH7AA900959MK/000001_1557820792.jpg',
#    'picS': '/items/DRAH7AA900959MK/000002_1557820792.jpg',
#    'price': 2190,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH6C-A9008F567',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 2TB 2.5吋 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆發揮系統極致效能\r\n◆持久率高達500tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 2TB 2.5吋 3D NAND固態硬碟(藍標)',
#    'originPrice': 9450,
#    'picB': '/items/DRAH6CA9008F567/000001_1557821067.jpg',
#    'picS': '/items/DRAH6CA9008F567/000002_1557821067.jpg',
#    'price': 9450,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7O-A9009M1H0',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD My Passport SSD 1TB 外接式固態硬碟 USB3.1 Gen2\\r\\n● wd my passport ssd，1tb 外接式固態硬碟 \r\n● usb 3.1 gen2(type-c) \r\n● 傳輸速度速度高達 515 mb s \r\n● 256 位 aes 硬體加密及 wd security™ 軟體 \r\n● 3年保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD My Passport SSD 1TB 外接式固態硬碟 USB3.1 Gen2',
#    'originPrice': 5990,
#    'picB': '/items/DRAH7OA9009M1H0/000001_1544608151.jpg',
#    'picS': '/items/DRAH7OA9009M1H0/000002_1544608151.jpg',
#    'price': 5990,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7O-A9009QY58',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s\r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)',
#    'originPrice': 1750,
#    'picB': '/items/DRAH7OA9009QY58/000001_1557825155.jpg',
#    'picS': '/items/DRAH7OA9009QY58/000002_1557825155.jpg',
#    'price': 1750,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH6D-A9008L285',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD 綠標 Green 120GB 2.5吋 SATAIII SSD\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s \r\n◆提升電腦日常運算效能\r\n◆耐用性40tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 120GB 2.5吋固態硬碟(綠標)',
#    'originPrice': 740,
#    'picB': '/items/DRAH6DA9008L285/000001_1557820667.jpg',
#    'picS': '/items/DRAH6DA9008L285/000002_1557820667.jpg',
#    'price': 740,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7O-A9009UD3E',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD 黑標 SN750 500GB NVMe PCIe SSD固態硬碟(WDS500G3X0C)\\r\\n讀3470m 寫2600m 五年保\r\n◆連續讀取3470mb s，連讀寫入2600mb s \r\n◆發揮系統極致效能\r\n◆介面 m.2 2280*  pcie gen3 8 gb s，最多 4 個通道\r\n◆五年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD 黑標 SN750 500GB NVMe PCIe SSD固態硬碟(WDS500G3X0C)',
#    'originPrice': 3450,
#    'picB': '/items/DRAH7OA9009UD3E/000001_1561345700.jpg',
#    'picS': '/items/DRAH7OA9009UD3E/000002_1557822835.jpg',
#    'price': 3450,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH5Z-A9009UKQZ',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH5Z',
#    'couponActid': [],
#    'describe': '技嘉 GIGABYTE AORUS RGB M.2 NVMe SSD 512GB (GP-ASM2NE2512GTTDR)\\r\\n規格尺寸:m.2 2280\r\n傳輸介面: pci-express 3.0 x4  nvme 1.3\r\n容量:512gb*                                                  \r\n保固: 5年保固\r\n連續讀取速度: 最高達 3480 mb s**\r\n連續寫入速度: 最高達2000 mb s**\r\n支援trim 指令及 s.m.a.r.t 自我檢測分析報告\r\n支援aes 256 rgb fusion 2.0 –與其他aorus設備完美同步燈光效果',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'AORUS RGB M.2 NVMe SSD 512GB (GP-ASM2NE2512GTTDR)',
#    'originPrice': 3190,
#    'picB': '/items/DRAH5ZA9009UKQZ/000001_1553591572.jpg',
#    'picS': '/items/DRAH5ZA9009UKQZ/000002_1553591572.jpg',
#    'price': 3190,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH7O-A9009DRZV',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD SSD 480GB 2.5吋固態硬碟(綠標)\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s \r\n◆提升電腦日常運算效能\r\n◆耐用性40tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD SSD 480GB 2.5吋固態硬碟(綠標)',
#    'originPrice': 1690,
#    'picB': '/items/DRAH7OA9009DRZV/000001_1557821601.jpg',
#    'picS': '/items/DRAH7OA9009DRZV/000002_1557821601.jpg',
#    'price': 1690,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH5W-A9008I75F',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH5E',
#    'couponActid': [],
#    'describe': 'SanDisk 進化版 SSD Plus 120GB 2.5吋SATAIII固態硬碟\\r\\n讀530m 寫310m tlc 三年保\r\n★持續讀寫速度530mb s；310mb s\r\n★搭配sandisk頂級tlc同步顆粒\r\n★dashboard 軟體可即時監控裝置狀態及軟體更新\r\n★7mm薄型設計\r\n★三年保固\r\n★展碁國際公司貨',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'SanDisk SSD Plus 120GB 2.5吋SATAIII固態硬碟(G27)',
#    'originPrice': 698,
#    'picB': '/items/DRAH5WA9008I75F/000001_1509343838.jpg',
#    'picS': '/items/DRAH5WA9008I75F/000002_1509343838.jpg',
#    'price': 698,
#    'publishDate': '',
#    'sellerId': ''},
#   {'BU': 'ec',
#    'Id': 'DRAH71-A9008S1L6',
#    'author': '',
#    'brand': '',
#    'cateId': 'DRAH7O',
#    'couponActid': [],
#    'describe': 'WD My Passport Wireless SSD 500GB 外接式Wi-Fi固態硬碟\\r\\n◆內建sd讀卡機\r\n◆快速ssd傳輸速度\r\n◆全天續航電池\r\n◆無線存取和4k串流\r\n◆內建行動電源\r\n◆全球有限二年保固',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'WD My Passport Wireless SSD 500GB 外接式Wi-Fi固態硬碟',
#    'originPrice': 6990,
#    'picB': '/items/DRAH71A9008S1L6/000001_1521118067.jpg',
#    'picS': '/items/DRAH71A9008S1L6/000002_1521118067.jpg',
#    'price': 6990,
#    'publishDate': '',
#    'sellerId': ''}],
#  'q': '\x08SSD',
#  'range': {'max': '', 'min': ''},
#  'subq': '',
#  'token': ['SSD'],
#  'totalPage': 100,
#  'totalRows': 9945}

# %%
PROD_NAME = 'SSD'
PCHOME_URL = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q='+ PROD_NAME +'&page=1&sort=sale/dc'
PCHOME_PROD_LINK_URL = 'https://24h.pchome.com.tw/prod/'
PCHOME_PIC_URL = 'https://d.ecimg.tw'
header = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

prod_list = []

for PAGE_NUM in range(1, 6):
    PCHOME_URL = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q='+ PROD_NAME +'&page='+ str(PAGE_NUM) +'&sort=sale/dc'
    resp = requests.get(PCHOME_URL, headers=header)
    
    if resp.status_code == 200: # 如果請求成功，則去抓產品列表
        data = json.loads(resp.text)
        prods = data['prods']

        for item in prods: # 抓細項
            prod_id = item['Id']
            prod_name = item['name']
            prod_price = str(item['price'])
            prod_pic = item['picS']

            obj = {
                'id': prod_id,
                'name': prod_name,
                'prod_price': prod_price,
                'url': PCHOME_PROD_LINK_URL + prod_id,
                'prod_pic': PCHOME_PIC_URL + prod_pic
            }
            prod_list.append(obj)
                
        time.sleep(1) 
    else: # 請求失敗
        print('pchome伺服器出現錯誤')
        
print(prod_list)
print(len(prod_list))
# Out:
# [{'id': 'DRAH6C-A9008F54N', 'name': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標)', 'prod_price': '2090', 'url': 'https://24h.pchome.com.tw/prod/DRAH6C-A9008F54N', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6CA9008F54N/000002_1557821136.jpg'}, {'id': 'DRAH5E-A9007CRTN', 'name': 'SanDisk SSD Plus 240GB 2.5吋SATAIII固態硬碟(G26)', 'prod_price': '938', 'url': 'https://24h.pchome.com.tw/prod/DRAH5E-A9007CRTN', 'prod_pic': 'https://d.ecimg.tw/items/DRAH5EA9007CRTN/000002_1488791017.jpg'}, {'id': 'DRAH6C-A9008F563', 'name': 'WD SSD 1TB 2.5吋 3D NAND固態硬碟(藍標)', 'prod_price': '3980', 'url': 'https://24h.pchome.com.tw/prod/DRAH6C-A9008F563', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6CA9008F563/000002_1557820146.jpg'}, {'id': 'DRAH5E-A9007CRVC', 'name': 'SanDisk SSD Plus 480GB 2.5吋SATAIII固態硬碟(G26)', 'prod_price': '1688', 'url': 'https://24h.pchome.com.tw/prod/DRAH5E-A9007CRVC', 'prod_pic': 'https://d.ecimg.tw/items/DRAH5EA9007CRVC/000002_1488791045.jpg'}, {'id': 'DRAH6C-A9008F54M', 'name': 'WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)', 'prod_price': '1390', 'url': 'https://24h.pchome.com.tw/prod/DRAH6C-A9008F54M', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6CA9008F54M/000002_1557820884.jpg'}, {'id': 'DRAH7P-A9009KY3G', 'name': 'SanDisk Extreme Pro 1TB M.2 NVMe 3D SSD', 'prod_price': '5688', 'url': 'https://24h.pchome.com.tw/prod/DRAH7P-A9009KY3G', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7PA9009KY3G/000002_1542622962.jpg'}, {'id': 'DRAH7P-A9009EKFR', 'name': 'SanDisk SSD Plus 1TB 2.5吋SATAIII固態硬碟(G26)', 'prod_price': '3388', 'url': 'https://24h.pchome.com.tw/prod/DRAH7P-A9009EKFR', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7PA9009EKFR/000002_1537158669.jpg'}, {'id': 'DRAH6C-A9008F56O', 'name': 'WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)', 'prod_price': '3980', 'url': 'https://24h.pchome.com.tw/prod/DRAH6C-A9008F56O', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6CA9008F56O/000002_1557822086.jpg'}, {'id': 'DRAH7O-A9009TD47', 'name': 'WD 黑標 SN750 1TB NVMe PCIe SSD固態硬碟', 'prod_price': '6690', 'url': 'https://24h.pchome.com.tw/prod/DRAH7O-A9009TD47', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7OA9009TD47/000002_1557823644.jpg'}, {'id': 'DRAH2M-A90099SG2', 'name': 'Seagate Fast SSD 500GB 外接式固態硬碟', 'prod_price': '3390', 'url': 'https://24h.pchome.com.tw/prod/DRAH2M-A90099SG2', 'prod_pic': 'https://d.ecimg.tw/items/DRAH2MA90099SG2/000002_1533794822.jpg'}, {'id': 'DRAH7A-A900959MK', 'name': 'WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標)', 'prod_price': '2190', 'url': 'https://24h.pchome.com.tw/prod/DRAH7A-A900959MK', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7AA900959MK/000002_1557820792.jpg'}, {'id': 'DRAH6C-A9008F567', 'name': 'WD SSD 2TB 2.5吋 3D NAND固態硬碟(藍標)', 'prod_price': '9450', 'url': 'https://24h.pchome.com.tw/prod/DRAH6C-A9008F567', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6CA9008F567/000002_1557821067.jpg'}, {'id': 'DRAH7O-A9009M1H0', 'name': 'WD My Passport SSD 1TB 外接式固態硬碟 USB3.1 Gen2', 'prod_price': '5990', 'url': 'https://24h.pchome.com.tw/prod/DRAH7O-A9009M1H0', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7OA9009M1H0/000002_1544608151.jpg'}, {'id': 'DRAH7O-A9009QY58', 'name': 'WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)', 'prod_price': '1750', 'url': 'https://24h.pchome.com.tw/prod/DRAH7O-A9009QY58', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7OA9009QY58/000002_1557825155.jpg'}, {'id': 'DRAH6D-A9008L285', 'name': 'WD SSD 120GB 2.5吋固態硬碟(綠標)', 'prod_price': '740', 'url': 'https://24h.pchome.com.tw/prod/DRAH6D-A9008L285', 'prod_pic': 'https://d.ecimg.tw/items/DRAH6DA9008L285/000002_1557820667.jpg'}, {'id': 'DRAH7O-A9009UD3E', 'name': 'WD 黑標 SN750 500GB NVMe PCIe SSD固態硬碟(WDS500G3X0C)', 'prod_price': '3450', 'url': 'https://24h.pchome.com.tw/prod/DRAH7O-A9009UD3E', 'prod_pic': 'https://d.ecimg.tw/items/DRAH7OA9009UD3E/000002_1557822835.jpg'}, {'id': 'DRAH5Z-A9009UKQZ', 'name': 'AORUS RGB M.2 NVMe SSD 512GB (GP-ASM2NE2512GTTDR)', 'prod_price': '3190', 'url': 'https://24h.pchome.com.tw/prod/DRAH5Z-A9009UKQZ', 'prod_pic': 'https://d.ecimg.tw/items/DRAH5ZA9009UKQZ/000002_1553591572.jpg'}, {'id': 'DR ...
# 100
